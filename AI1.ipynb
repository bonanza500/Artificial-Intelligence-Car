# %%
import warnings

# %%
warnings.filterwarnings('ignore')

# %%
import pandas as pd

# %%
data = pd.read_csv(r"C:\Users\yajam\OneDrive\Documents\car_data_new.csv");

# %%
data.head()
# Out:
#   Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 0     ritz  2014      335000000      559000000       27000    Petrol
# 1      sx4  2023      475000000      954000000       43000    Diesel
# 2     ciaz  2017      725000000      985000000        6900    Petrol
# 3  wagon r  2011      285000000      415000000        5200    Petrol
# 4    swift  2014       46000000      687000000       42450    Diesel
#
#   Seller_Type Transmission  Owner
# 0      Dealer       Manual      0
# 1      Dealer       Manual      0
# 2      Dealer       Manual      0
# 3      Dealer       Manual      0
# 4      Dealer       Manual      0

# %%
data.tail()
# Out:
#     Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 296     city  2016       95000000      116000000       33988    Diesel
# 297     brio  2015        4000000       59000000       60000    Petrol
# 298     city  2009      335000000       11000000       87934    Petrol
# 299     city  2017      115000000      125000000        9000    Diesel
# 300     brio  2016       53000000       59000000        5464    Petrol
#
#     Seller_Type Transmission  Owner
# 296      Dealer       Manual      0
# 297      Dealer       Manual      0
# 298      Dealer       Manual      0
# 299      Dealer       Manual      0
# 300      Dealer       Manual      0

# %%
data.shape
# Out:
# (301, 9)

# %%
print("Number of rows", data.shape[0])
# Out:
# Number of rows 301

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 301 entries, 0 to 300
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Car_Name       301 non-null    object
#  1   Year           301 non-null    int64
#  2   Selling_Price  301 non-null    int64
#  3   Present_Price  301 non-null    int64
#  4   Kms_Driven     301 non-null    int64
#  5   Fuel_Type      301 non-null    object
#  6   Seller_Type    301 non-null    object
#  7   Transmission   301 non-null    object
#  8   Owner          301 non-null    int64
# dtypes: int64(5), object(4)
# memory usage: 21.3+ KB

# %%
data.isnull().sum()
# Out:
# Car_Name         0
# Year             0
# Selling_Price    0
# Present_Price    0
# Kms_Driven       0
# Fuel_Type        0
# Seller_Type      0
# Transmission     0
# Owner            0
# dtype: int64

# %%
data.describe()
# Out:
#               Year  Selling_Price  Present_Price     Kms_Driven       Owner
# count   301.000000   3.010000e+02   3.010000e+02     301.000000  301.000000
# mean   2015.023256   2.462724e+08   5.153322e+08   36947.205980    0.043189
# std       4.118591   3.611175e+08   7.416092e+08   38886.883882    0.247915
# min    2003.000000   1.000000e+06   7.000000e+06     500.000000    0.000000
# 25%    2013.000000   2.700000e+07   6.800000e+07   15000.000000    0.000000
# 50%    2015.000000   6.500000e+07   1.250000e+08   32000.000000    0.000000
# 75%    2017.000000   3.510000e+08   7.270000e+08   48767.000000    0.000000
# max    2023.000000   2.075000e+09   3.623000e+09  500000.000000    3.000000

# %%
data.head(1)
# Out:
#   Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 0     ritz  2014      335000000      559000000       27000    Petrol
#
#   Seller_Type Transmission  Owner
# 0      Dealer       Manual      0

# %%
import datetime

# %%
date_time = datetime.datetime.now()

# %%
data['Age']=date_time.year - data['Year']

# %%
data.drop('Year', axis = 1, inplace = True)

# %%
data.head()
# Out:
#   Car_Name  Selling_Price  Present_Price  Kms_Driven Fuel_Type Seller_Type  \
# 0     ritz      335000000      559000000       27000    Petrol      Dealer
# 1      sx4      475000000      954000000       43000    Diesel      Dealer
# 2     ciaz      725000000      985000000        6900    Petrol      Dealer
# 3  wagon r      285000000      415000000        5200    Petrol      Dealer
# 4    swift       46000000      687000000       42450    Diesel      Dealer
#
#   Transmission  Owner  Age
# 0       Manual      0   10
# 1       Manual      0    1
# 2       Manual      0    7
# 3       Manual      0   13
# 4       Manual      0   10

# %%
import seaborn as sns

# %%
sns.boxplot(data['Selling_Price'])
# Out:
# <Axes: ylabel='Selling_Price'>

# %%
sorted(data['Selling_Price'], reverse = True)
# Out:
# [2075000000,
#  1999000000,
#  1975000000,
#  1875000000,
#  1473000000,
#  1425000000,
#  1175000000,
#  1145000000,
#  1125000000,
#  1125000000,
#  1125000000,
#  1025000000,
#  1011000000,
#  965000000,
#  925000000,
#  925000000,
#  925000000,
#  915000000,
#  899000000,
#  875000000,
#  865000000,
#  855000000,
#  835000000,
#  825000000,
#  825000000,
#  775000000,
#  775000000,
#  775000000,
#  745000000,
#  745000000,
#  745000000,
#  725000000,
#  725000000,
#  705000000,
#  695000000,
#  685000000,
#  675000000,
#  645000000,
#  625000000,
#  625000000,
#  615000000,
#  595000000,
#  595000000,
#  585000000,
#  585000000,
#  575000000,
#  575000000,
#  565000000,
#  535000000,
#  525000000,
#  525000000,
#  525000000,
#  525000000,
#  525000000,
#  525000000,
#  525000000,
#  515000000,
#  511000000,
#  495000000,
#  495000000,
#  485000000,
#  475000000,
#  475000000,
#  475000000,
#  475000000,
#  475000000,
#  475000000,
#  465000000,
#  435000000,
#  415000000,
# ...

# %%
data = data[~(data['Selling_Price'] >=1999000000) & (data['Selling_Price']<=2075000000)]

# %%
data.shape
# Out:
# (299, 9)

# %%
data['Fuel_Type'].unique()
# Out:
# array(['Petrol', 'Diesel', 'CNG'], dtype=object)

# %%
data['Fuel_Type'] = data['Fuel_Type'].map({'Petrol':0,'Diesel':1,'CNG':2})

# %%
data['Fuel_Type'].unique()
# Out:
# array([0, 1, 2], dtype=int64)

# %%
data['Seller_Type'].unique()
# Out:
# array(['Dealer', 'Individual'], dtype=object)

# %%
data['Seller_Type'] = data['Seller_Type'].map({'Dealer':0,'Individual':1})

# %%
data['Seller_Type'].unique()
# Out:
# array([0, 1], dtype=int64)

# %%
data['Transmission'].unique()
# Out:
# array(['Manual', 'Automatic'], dtype=object)

# %%
data['Transmission'] = data['Transmission'].map({'Manual':0,'Automatic':1})

# %%
data['Transmission'].unique()
# Out:
# array([0, 1], dtype=int64)

# %%
data.head()
# Out:
#   Car_Name  Selling_Price  Present_Price  Kms_Driven  Fuel_Type  Seller_Type  \
# 0     ritz      335000000      559000000       27000          0            0
# 1      sx4      475000000      954000000       43000          1            0
# 2     ciaz      725000000      985000000        6900          0            0
# 3  wagon r      285000000      415000000        5200          0            0
# 4    swift       46000000      687000000       42450          1            0
#
#    Transmission  Owner  Age
# 0             0      0   10
# 1             0      0    1
# 2             0      0    7
# 3             0      0   13
# 4             0      0   10

# %%
X = data.drop(['Car_Name','Selling_Price'], axis = 1)
y = data['Selling_Price']

# %%
X
# Out:
#      Present_Price  Kms_Driven  Fuel_Type  Seller_Type  Transmission  Owner  \
# 0        559000000       27000          0            0             0      0
# 1        954000000       43000          1            0             0      0
# 2        985000000        6900          0            0             0      0
# 3        415000000        5200          0            0             0      0
# 4        687000000       42450          1            0             0      0
# ..             ...         ...        ...          ...           ...    ...
# 296      116000000       33988          1            0             0      0
# 297       59000000       60000          0            0             0      0
# 298       11000000       87934          0            0             0      0
# 299      125000000        9000          1            0             0      0
# 300       59000000        5464          0            0             0      0
#
#      Age
# 0     10
# 1      1
# 2      7
# 3     13
# ...

# %%
y
# Out:
# 0      335000000
# 1      475000000
# 2      725000000
# 3      285000000
# 4       46000000
#          ...
# 296     95000000
# 297      4000000
# 298    335000000
# 299    115000000
# 300     53000000
# Name: Selling_Price, Length: 299, dtype: int64

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size = 0.20, random_state = 42)

# %%
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import GradientBoostingRegressor
from xgboost import XGBRegressor

# %%
lr = LinearRegression()
lr.fit(X_train, y_train)

rf = RandomForestRegressor()
rf.fit(X_train, y_train)

xgb = GradientBoostingRegressor()
xgb.fit(X_train, y_train)

xg = XGBRegressor()
xg.fit(X_train, y_train)
# Out:
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, device=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              gamma=None, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=None, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=None, max_leaves=None,
#              min_child_weight=None, missing=nan, monotone_constraints=None,
#              multi_strategy=None, n_estimators=None, n_jobs=None,
#              num_parallel_tree=None, random_state=None, ...)

# %%
y_pred1 = lr.predict(X_test)
y_pred2 = rf.predict(X_test)
y_pred3 = xgb.predict(X_test)
y_pred4 = xg.predict(X_test)

# %%
from sklearn import metrics

# %%
score1 = metrics.r2_score(y_test,y_pred1)
score2 = metrics.r2_score(y_test,y_pred2)
score3 = metrics.r2_score(y_test,y_pred3)
score4 = metrics.r2_score(y_test,y_pred4)

# %%
print(score1, score2, score3, score4)
# Out:
# 0.12588586948855762 0.2193722837005514 -0.1488256278412352 0.3411184549331665

# %%
xg = XGBRegressor()
xg_final = xg.fit(X,y)

# %%
import joblib

joblib.dump(xg_final, 'car_price_predictor')
# Out:
# ['car_price_predictor']

# %%
model = joblib.load('car_price_predictor')

# %%
xg_final.save_model('xgb_model.json')

# %%
import joblib
model = joblib.load('car_price_predictor')

# %%
from sklearn.ensemble import GradientBoostingRegressor
import joblib

# Assume 'model' is your GradientBoostingRegressor instance
model = GradientBoostingRegressor()
# Train the model here...

# Save the model
joblib.dump(model, 'gradient_boosting_model.pkl')
print("Model saved as 'gradient_boosting_model.pkl'")
# Out:
# Model saved as 'gradient_boosting_model.pkl'

# %%
import joblib

# %%
joblib.dump(xg_final,'car_price_predictor')
# Out:
# ['car_price_predictor']

# %%
model = joblib.load('car_price_predictor')

# %%
import pandas as pd
data_new = pd.DataFrame({
    'Present_Price': 6000000,
    'Kms_Driven': 27000,
    'Fuel_Type':0,
    'Seller_Type':0,
    'Transmission':0,
    'Owner':0,
    'Age':8
}, index = [0] )

# %%
model.predict(data_new)
# Out:
# array([2.23891456e+08])

# %%
from tkinter import *
import pandas as pd  
import joblib 

def show_entry_fields():
    try:

        p1 = float(e1.get())
        p2 = float(e2.get())
        p3 = float(e3.get())
        p4 = float(e4.get())
        p5 = float(e5.get())
        p6 = float(e6.get())
        p7 = float(e7.get())

        model = joblib.load('car_price_predictor')

        data_new = pd.DataFrame({
            'Present_Price': [p1],
            'Kms_Driven': [p2],
            'Fuel_Type': [p3],
            'Seller_Type': [p4],
            'Transmission': [p5],
            'Owner': [p6],
            'Age': [p7]
        })

        result = model.predict(data_new)

        result_label.config(text=f"Car Purchase Amount: {result[0]:.2f}")
    except Exception as e:
        result_label.config(text=f"Error: {e}")

master = Tk()
master.title("Car Price Prediction Using Machine Learning")

Label(master, text="Car Price Prediction Using Machine Learning", bg="black", fg="white").grid(row=0, column=0, columnspan=2, pady=10)

Label(master, text="Present_Price").grid(row=1, column=0, pady=5)
Label(master, text="Kms_Driven").grid(row=2, column=0, pady=5)
Label(master, text="Fuel_Type").grid(row=3, column=0, pady=5)
Label(master, text="Seller_Type").grid(row=4, column=0, pady=5)
Label(master, text="Transmission").grid(row=5, column=0, pady=5)
Label(master, text="Owner").grid(row=6, column=0, pady=5)
Label(master, text="Age").grid(row=7, column=0, pady=5)

e1 = Entry(master)
e2 = Entry(master)
e3 = Entry(master)
e4 = Entry(master)
e5 = Entry(master)
e6 = Entry(master)
e7 = Entry(master)

e1.grid(row=1, column=1)
e2.grid(row=2, column=1)
e3.grid(row=3, column=1)
e4.grid(row=4, column=1)
e5.grid(row=5, column=1)
e6.grid(row=6, column=1)
e7.grid(row=7, column=1)

Button(master, text="Predict", command=show_entry_fields).grid(row=8, column=0, columnspan=2, pady=10)

result_label = Label(master, text="", fg="blue")
result_label.grid(row=9, column=0, columnspan=2, pady=10)

mainloop()

# %%
import joblib
model = joblib.load('car_price_predictor')

# %%
xg_final.save_model('xgb_model.json')

# %%
import os
print("Current Working Directory:", os.getcwd())
# Out:
# Current Working Directory: C:\Users\yajam
